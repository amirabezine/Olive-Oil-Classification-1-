# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
# Load csv file
df = pd.read_csv(r"KNN_data.csv")

# Display the first few rows
df.head()
# Out:
#    eicosenoic  palmitic  palmitoleic   stearic     oleic  linoleic  linolenic  \
# 0   -0.942188 -0.954203    -0.069347  1.217049 -1.222068  0.286817   0.064073
# 1   -0.865647 -0.991878    -0.123676  0.943603 -0.778552 -0.111749   0.111567
# 2   -1.907782 -1.349789     0.473945  1.912659 -1.722549 -0.111749   0.206556
# 3   -1.583955 -1.293277     0.310957  1.526476 -1.437722  1.402803   0.918972
# 4   -1.083494 -1.104903     0.827084  1.092319 -1.222068  1.402803   1.013961
#
#    arachidic  class
# 0   0.872009      2
# 1   0.872009      2
# 2   0.872009      2
# 3   1.296728      2
# 4   2.075379      2

# %%
print(df.shape)
# Out:
# (494, 9)

# %%
# Separate the features and the class column
features = df.drop('class', axis=1)
classes = df['class']

# Split the dataset into training and test datasets (80% for training, 20% for testing)
X_train, X_test, y_train, y_test = train_test_split(features, classes, test_size=0.2, random_state=42)

print("Training dataset size:", len(X_train))
print("Test dataset size:", len(X_test))
# Out:
# Training dataset size: 395
# Test dataset size: 99

# %%
df.describe()
# Out:
#        eicosenoic    palmitic  palmitoleic     stearic       oleic  \
# count  494.000000  494.000000   494.000000  494.000000  494.000000
# mean     0.004742    0.002043     0.008903   -0.004258   -0.000978
# std      1.001937    0.997630     1.008828    1.000162    1.001865
# min     -3.680002   -2.084448    -2.079525   -2.436099   -2.133513
# 25%     -0.815601   -0.761120    -0.660176   -0.780429   -0.867052
# 50%     -0.109068   -0.294894    -0.123676    0.008128    0.193928
# 75%      0.754962    0.816513     0.501109    0.940005    0.836822
# max      3.049721    2.907465     3.978174    2.625059    2.024956
#
#          linoleic   linolenic   arachidic       class
# count  494.000000  494.000000  494.000000  494.000000
# mean     0.023150    0.011963    0.018273    1.030364
# std      1.002386    1.002079    1.002686    0.887763
# min     -2.582859   -2.785591   -1.110012    0.000000
# 25%     -0.430602   -0.398998   -1.039226    0.000000
# 50%      0.047678    0.159061    0.093358    1.000000
# 75%      0.685383    0.539017    0.801223    2.000000
# max      3.315920    2.201321    2.924817    2.000000

# %%
print(y_train)
# Out:
# 438    2
# 56     2
# 351    2
# 222    0
# 362    2
#       ..
# 106    0
# 270    0
# 348    1
# 435    2
# 102    0
# Name: class, Length: 395, dtype: int64

# %% [markdown]
# NAIVE BAYES MODEL

# %%
# Train a Naive Bayes classifier
nb = GaussianNB()
nb.fit(X_train, y_train)

# Make predictions on the test data
y_pred = nb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print(f"Confusion matrix: \n{cm}")
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
# Out:
# Accuracy: 0.9494949494949495
# Precision: 0.9458689458689458
# Recall: 0.9493589743589744
# F1-score: 0.9474564127059947
# Confusion matrix:
# [[33  0  0]
#  [ 0 24  2]
#  [ 0  3 37]]

# %% [markdown]
# KNN MODEL

# %%
# Import KNeighborsClassifier from scikit-learn
from sklearn.neighbors import KNeighborsClassifier

# Train a KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# print(f"Confusion matrix: \n{cm}")
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
# Out:
# Accuracy: 0.9696969696969697
# Precision: 0.9704065040650406
# Recall: 0.966025641025641
# F1-score: 0.9680464778503994

# %% [markdown]
# LDA (Linear Descriminate Analysis)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Create LDA model
lda = LinearDiscriminantAnalysis()

# Train the model
lda.fit(X_train, y_train)

# Predict on the test data
y_pred = lda.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# print(f"Confusion matrix: \n{cm}")
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
# Out:
# Accuracy: 0.9595959595959596
# Precision: 0.963963963963964
# Recall: 0.9666666666666667
# F1-score: 0.9634085213032582

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Define and train the decision tree classifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set up the figure size for the plot
plt.figure(figsize=(20, 10))

# Visualize the decision tree
plot_tree(clf, filled=True, feature_names=df.columns[:-1], class_names=['Class 1', 'Class 2', 'Class 3'], rounded=True)

# Show the plot
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# print(f"Confusion matrix: \n{cm}")
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
# Out:
# Accuracy: 0.9494949494949495
# Precision: 0.9499687304565354
# Recall: 0.9475912975912976
# F1-score: 0.9486546375435264

# %% [markdown]
# Artificial Neural Networks (ANN)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# Scale the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convert class labels to one-hot encoded vectors
y_train_onehot = to_categorical(y_train)
y_test_onehot = to_categorical(y_test)

# Create the ANN model
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train_onehot, epochs=100, batch_size=32, validation_split=0.2)

# Predict the test dataset
y_pred_onehot = model.predict(X_test)
y_pred = np.argmax(y_pred_onehot, axis=1)

# Calculate the metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_mat = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# Plot the loss function
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Function Plot')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 27ms/step - loss: 0.8362 - accuracy: 0.6994 - val_loss: 0.7515 - val_accuracy: 0.7848
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7155 - accuracy: 0.7943 - val_loss: 0.6342 - val_accuracy: 0.8228
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6130 - accuracy: 0.8513 - val_loss: 0.5353 - val_accuracy: 0.8987
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5245 - accuracy: 0.9209 - val_loss: 0.4528 - val_accuracy: 0.9747
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4511 - accuracy: 0.9525 - val_loss: 0.3843 - val_accuracy: 0.9873
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3897 - accuracy: 0.9747 - val_loss: 0.3286 - val_accuracy: 0.9873
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3387 - accuracy: 0.9778 - val_loss: 0.2817 - val_accuracy: 1.0000
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2932 - accuracy: 0.9778 - val_loss: 0.2417 - val_accuracy: 1.0000
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2542 - accuracy: 0.9810 - val_loss: 0.2083 - val_accuracy: 0.9873
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2219 - accuracy: 0.9842 - val_loss: 0.1798 - val_accuracy: 0.9873
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1935 - accuracy: 0.9842 - val_loss: 0.1556 - val_accuracy: 0.9873
# Epoch 12/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1694 - accuracy: 0.9842 - val_loss: 0.1361 - val_accuracy: 0.9873
# Epoch 13/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1494 - accuracy: 0.9842 - val_loss: 0.1198 - val_accuracy: 0.9873
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1319 - accuracy: 0.9842 - val_loss: 0.1063 - val_accuracy: 0.9873
# Epoch 15/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1179 - accuracy: 0.9842 - val_loss: 0.0961 - val_accuracy: 0.9873
# Epoch 16/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1061 - accuracy: 0.9842 - val_loss: 0.0878 - val_accuracy: 0.9873
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0959 - accuracy: 0.9842 - val_loss: 0.0812 - val_accuracy: 0.9873
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0879 - accuracy: 0.9842 - val_loss: 0.0750 - val_accuracy: 0.9747
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0809 - accuracy: 0.9873 - val_loss: 0.0705 - val_accuracy: 0.9747
# Epoch 20/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0752 - accuracy: 0.9873 - val_loss: 0.0676 - val_accuracy: 0.9747
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0699 - accuracy: 0.9873 - val_loss: 0.0639 - val_accuracy: 0.9747
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0657 - accuracy: 0.9873 - val_loss: 0.0609 - val_accuracy: 0.9747
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.
100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0195 - accuracy: 0.9968 - val_loss: 0.0309 - val_accuracy: 0.9873
# Epoch 58/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0191 - accuracy: 0.9968 - val_loss: 0.0309 - val_accuracy: 0.9873
# Epoch 59/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0186 - accuracy: 0.9968 - val_loss: 0.0301 - val_accuracy: 0.9873
# Epoch 60/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 0.9968 - val_loss: 0.0296 - val_accuracy: 0.9873
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0178 - accuracy: 0.9968 - val_loss: 0.0293 - val_accuracy: 0.9873
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.0298 - val_accuracy: 0.9873
# Epoch 63/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0173 - accuracy: 0.9968 - val_loss: 0.0279 - val_accuracy: 0.9873
# Epoch 64/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9873
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.9968 - val_loss: 0.0288 - val_accuracy: 0.9873
# Epoch 66/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9968 - val_loss: 0.0277 - val_accuracy: 0.9873
# Epoch 67/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9873
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9873
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9873
# Epoch 70/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 0.9968 - val_loss: 0.0282 - val_accuracy: 0.9873
# Epoch 71/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9873
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9873
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0140 - accuracy: 0.9968 - val_loss: 0.0281 - val_accuracy: 0.9873
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9873
# Epoch 75/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9873
# Epoch 76/100
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9873
# Epoch 77/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9873
# Epoch 78/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9873
# Epoch 79/100
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9873
# Epoch 80/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9873
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9873
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9873
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9873
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9873
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9873
# Epoch 86/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9873
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9873
# Epoch 88/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9873
# Epoch 89/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9873
# Epoch 90/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9873
# Epoch 91/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9873
# Epoch 92/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9873
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9873
# Epoch 94/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9873
# Epoch 95/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9873
# Epoch 96/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9873
# Epoch 97/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9873
# Epoch 98/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9873
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9873
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9873
# 4/4 [==============================] - 0s 2ms/step
# Accuracy: 0.98989898989899
# Precision: 0.9901453559990147
# Recall: 0.98989898989899
# F1-score: 0.9898623123023993

# %%
from ann_visualizer.visualize import ann_viz

ann_viz(model, view=True, filename="network.gv", title="ANN Model Architecture")

# %% [markdown]
# SVM

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import classification_report, confusion_matrix


# define the SVM classifier
svm_clf = svm.SVC()

# define the parameter grid for hyperparameter tuning using grid search
param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}

# perform grid search cross-validation to find the best hyperparameters
grid_search = GridSearchCV(svm_clf, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# print the best hyperparameters and the mean cross-validation score
print("Best hyperparameters: ", grid_search.best_params_)
print("Mean cross-validation score: ", grid_search.best_score_)

# predict on the test set using the best model
y_pred = grid_search.predict(X_test)

# print the classification report and confusion matrix
print("Classification report: \n", classification_report(y_test, y_pred))
# print("Confusion matrix: \n", confusion_matrix(y_test, y_pred))
# plot_confusion_matrix(svm_model, X_test, y_test)
# plt.show()

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
# Out:
# Best hyperparameters:  {'C': 0.1, 'kernel': 'linear'}
# Mean cross-validation score:  0.9873417721518987
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       0.96      0.92      0.94        26
#            2       0.95      0.97      0.96        40
#
#     accuracy                           0.97        99
#    macro avg       0.97      0.97      0.97        99
# weighted avg       0.97      0.97      0.97        99

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
# cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# print(f"Confusion matrix: \n{cm}")
# Out:
# Accuracy: 0.9696969696969697
# Precision: 0.9704065040650406
# Recall: 0.966025641025641
# F1-score: 0.9680464778503994
